# %%
# load Cleaned_Code\Add_1_scraped.csv
# load Cleaned_Code\Add_1.csv
import pandas as pd
# load Cleaned_Code\Add_1.csv
df1 = pd.read_csv('Add_1_5.csv')
# load Cleaned_Code\Add_1_scraped.csv
df2 = pd.read_csv('Add_1_5_scraped.csv')
df1
# Out:
#                                           clean_line1  \
# 0              Coalville , 84017 Holiday Hills ( 66 )
# 1                      Coalville , 84017 Hills ( 66 )
# 2          D Coalville , 84017 Holiday Hills ( 66 ) )
# 3          D Coalville ( 84017 ) Holiday Hills ( 66 )
# 4          D Coalville ( 84017 ) Holiday Hills ( 66 )
# ...                                               ...
# 2328       Corning ( 96021 ) Love's Travel Stop # 410
# 2329          , 96021 Flying J Travel Plaza # 0510154
# 2330  Corning , 96021 Flying J Travel Plaza # 0510154
# 2331       A Grenada ( 96038 ) 3 J's Food Mart ( 76 )
# 2332  A Grenada ( 96038 ) 3 J's Food Mart ( 76 ) Dr )
#
#                                             clean_line2  \
# 0                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 1         435-336-4421 I-80 Holiday Exit 162 ( UT 280 )
# 2               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# 3                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 4               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# ...                                                 ...
# 2328          2 530-824-8767 I-5 Exit 630 ( South Ave )
# 2329  CCorning 2530-824-8770 I-5 Exit 630 ( South Ave )
# 2330          2 530-824-8770 I-5 Exit 630 ( South Ave )
# 2331             530-436-2208 I-5 Exit 766 ( CA A12 E )
# 2332                     530-436-2208 I-5 Exit 766 ( CA
#
#                                       line3       city  zip_code  \
# 0                                        MO  Coalville     84017
# 1                                M <U+25A1>  Coalville     84017
# 2              M <U+2610> <U+2610> <U+2610>  Coalville     84017
# 3                       M <U+25A1> <U+2610>  Coalville     84017
# 4                          D M <U+25A1> D D  Coalville     84017
# ...                                     ...        ...       ...
# 2328                            24 XL 24 24    Corning     96021
# 2329                               XL 24 45        NaN     96021
# 2330                      124 HRS XL 24 HRS    Corning     96021
# 2331           <U+2610><U+2610> XL <U+2610>    Grenada     96038
# 2332  <U+2610><U+2610> XL <U+25A1> <U+2610>    Grenada     96038
#
#                                 label         phone  year major_city state  \
# 0                Holiday Hills ( 66 )  435-336-4421  2006  Coalville    UT
# 1                        Hills ( 66 )  435-336-4421  2007  Coalville    UT
# 2              Holiday Hills ( 66 ) )  435-336-4421  2008  Coalville    UT
# 3                Holiday Hills ( 66 )  435-336-4421  2014  Coalville    UT
# 4                Holiday Hills ( 66 )  435-336-4421  2015  Coalville    UT
# ...                               ...           ...   ...        ...   ...
# 2328         Love's Travel Stop # 410  530-824-8767  2016    Corning    CA
# 2329  Flying J Travel Plaza # 0510154  530-824-8770  2007    Corning    CA
# 2330  Flying J Travel Plaza # 0510154  530-824-8770  2008    Corning    CA
# 2331           3 J's Food Mart ( 76 )  530-436-2208  2014    Grenada    CA
# 2332      3 J's Food Mart ( 76 ) Dr )  530-436-2208  2015    Grenada    CA
#
#       ... Exit_From_Address Exit_From_Label Flagged Flag_Reason  \
# 0     ...               162             NaN   False         NaN
# 1     ...               162             NaN   False         NaN
# 2     ...               162             NaN   False         NaN
# 3     ...               162             NaN   False         NaN
# 4     ...               162             NaN   False         NaN
# ...   ...               ...             ...     ...         ...
# 2328  ...               630             NaN   False         NaN
# 2329  ...               630             NaN   False         NaN
# 2330  ...               630             NaN   False         NaN
# 2331  ...               766             NaN   False         NaN
# 2332  ...               766             NaN   False         NaN
#
#      Is_Unclear_OCR Main_Road  Secondary_Road  Exit_Number_2 Exit_Number_3  \
# 0             False      I-80             NaN            NaN           NaN
# 1             False      I-80             NaN            NaN           NaN
# 2             False      I-80             NaN            NaN           NaN
# 3             False      I-80             NaN            NaN           NaN
# 4             False      I-80             NaN            NaN           NaN
# ...             ...       ...             ...            ...           ...
# 2328          False       I-5             NaN            NaN           NaN
# 2329          False       I-5             NaN            NaN           NaN
# 2330          False       I-5             NaN            NaN           NaN
# 2331          False       I-5             NaN            NaN           NaN
# 2332          False       I-5             NaN            NaN           NaN
#
#       Tertiary_Road
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 2328            NaN
# 2329            NaN
# 2330            NaN
# 2331            NaN
# 2332            NaN
#
# [2333 rows x 25 columns]

# %%
# Convert any float column to nullable integer
df1['Exit_Number_2'] = pd.to_numeric(df1['Exit_Number_2'], downcast='integer').astype('Int64')
df1['Exit_Number_3'] = pd.to_numeric(df1['Exit_Number_3'], downcast='integer').astype('Int64')

# %%
# Manually adding 122 to Exit_Number_2 and 17 to Exit_Number_3 for rows 75, 76, and 77
rows_to_update = [75, 76, 77]

# Check if column Exit_Number_3 exists, if not create it
if 'Exit_Number_3' not in df1.columns:
    df1['Exit_Number_3'] = None

# Update the values
for row in rows_to_update:
    df1.at[row, 'Exit_Number_2'] = 122  # Using string type to match previous conversion
    df1.at[row, 'Exit_Number_3'] = 17
    df1.at[row, 'Tertiary_Road'] = 'UT 201'
print("Values updated for rows 75, 76, and 77")
print("\nUpdated values:")
print(df1.loc[75:77, ['Exit_Number_2', 'Exit_Number_3']])
# Out:
# Values updated for rows 75, 76, and 77
#
# Updated values:
#     Exit_Number_2  Exit_Number_3
# 75            122             17
# 76            122             17
# 77            122             17

# %%
# Converting Exit_Number_2 and Exit_Number_3 columns to string type for consistency
df1['Exit_Number_2'] = df1['Exit_Number_2'].astype(str)
df1['Exit_Number_3'] = df1['Exit_Number_3'].astype(str)

# Replace "nan" and "None" strings with empty strings or actual NaN
#df1['Exit_Number_2'] = df1['Exit_Number_2'].replace(['nan', 'None'], '')
#df1['Exit_Number_3'] = df1['Exit_Number_3'].replace(['nan', 'None'], '')

print("Columns converted to string type")
print("\nData types of columns:")
print(f"Exit_Number_2: {df1['Exit_Number_2'].dtype}")
print(f"Exit_Number_3: {df1['Exit_Number_3'].dtype}")

# Check the updated rows again
print("\nFinal values for rows 75, 76, and 77:")
print(df1.loc[75:77, ['Exit_Number_2', 'Exit_Number_3']])
# Out:
# Columns converted to string type
#
# Data types of columns:
# Exit_Number_2: object
# Exit_Number_3: object
#
# Final values for rows 75, 76, and 77:
#    Exit_Number_2 Exit_Number_3
# 75           122            17
# 76           122            17
# 77           122            17

# %%
def compare_random_rows(dataframe, n=2, columns=None, seed=None, address_type=None):
    """
    Compare random rows from a dataframe.
    
    Parameters:
    -----------
    dataframe : pandas.DataFrame
        The dataframe to sample rows from
    n : int, default 2
        Number of random rows to compare
    columns : list, default None
        List of columns to include in comparison. If None, all columns are used.
    seed : int, default None
        Random seed for reproducibility
    address_type : str or list, default None
        Filter rows by specific address type(s). If None, all address types are considered.
        Can be a single string or a list of address types.
    
    Returns:
    --------
    pandas.DataFrame
        A dataframe with the randomly selected rows
    """
    import numpy as np
    
    # Set random seed if provided
    if seed is not None:
        np.random.seed(seed)
    
    # Filter by address type if specified
    if address_type is not None:
        if 'Address_Type' in dataframe.columns:
            # Handle both single string and list of address types
            if isinstance(address_type, str):
                filtered_df = dataframe[dataframe['Address_Type'] == address_type]
            else:  # Assume it's a list or other iterable
                filtered_df = dataframe[dataframe['Address_Type'].isin(address_type)]
                
            if filtered_df.empty:
                raise ValueError(f"No rows found with address type(s): {address_type}")
        else:
            raise ValueError("'Address_Type' column not found in the dataframe")
    else:
        filtered_df = dataframe
    
    # Randomly sample n rows
    if n > len(filtered_df):
        print(f"Warning: Requested {n} rows but only {len(filtered_df)} rows available. Using all available rows.")
        n = len(filtered_df)
    
    random_indices = np.random.choice(filtered_df.index, size=n, replace=False)
    
    # Get the selected columns or use all if None
    if columns is None:
        columns = dataframe.columns
    
    # Return the sampled rows with the selected columns
    return dataframe.loc[random_indices, columns]

# Example usage for comparing random rows
# You can specify which columns you're interested in comparing
columns_to_compare = ['address_standardized_ON_parenthesis', 'address_standardized_OFF_parenthesis',
                      'Main_Road','Exit_Number','Secondary_Road','Exit_Number_2','clean_line1', 'clean_line2','line3','Is_Unclear_OCR','Address_Type']

# Filter to only include columns that exist in df1
available_columns = [col for col in columns_to_compare if col in df1.columns]

# Compare 3 random rows using the specified columns
random_comparison = compare_random_rows(df1, n=20, columns=available_columns)
#display(random_comparison)

# Example of how to use the address_type parameter (commented out)
# Compare random rows of a specific address type
random_comparison_by_type = compare_random_rows(df1, n=10, columns=available_columns, address_type='empty')
display(random_comparison_by_type)
# Out:
#      address_standardized_ON_parenthesis address_standardized_OFF_parenthesis  \
# 873                      ( S of CA 905 )                    La Media & Airway
# 722                    ( at state line )                               US 395
# 1579                      ( W of UT 13 )                                UT 83
# 1654                                 NaN                     AZ 85 & 35th Ave
# 1103                                 NaN                     US 99 & CA 190 W
# 2175                      ( E of CA 59 )                        CA 152 & Rd 4
# 915              ( betw CA 86 & CA 111 )                       90480-66th Ave
# 206                                  NaN                        US 50 & UT 24
# 2273                                 NaN                  US 101 & N State St
# 1483                                 NaN              CA 70 & Georgia Station
#
#      Main_Road Exit_Number   Secondary_Road Exit_Number_2  \
# 873   La Media         NaN           Airway          <NA>
# 722     US 395         NaN              NaN          <NA>
# 1579     UT 83         NaN              NaN          <NA>
# 1654     AZ 85         NaN         35th Ave          <NA>
# 1103     US 99         NaN           CA 190          <NA>
# 2175    CA 152         NaN             Rd 4          <NA>
# 915   66th Ave         NaN              NaN          <NA>
# 206      US 50         NaN            UT 24          <NA>
# 2273    US 101         NaN       N State St          <NA>
# 1483     CA 70         NaN  Georgia Station          <NA>
#
#                                             clean_line1  \
# 873             Otay Mesa ( 92154 ) TruckNet Truck Stop
# 722               Bordertown , 89506 Winners Corner 1st
# 1579        Corinne ( 84307 ) Bear River Valley Co - Op
# 1654                F Phoenix ( 85009 ) Circle K # 2885
# 1103  Tipton ( 93272 ) Town & Country Market Hope N ...
# 2175            F Chowchilla , 93610 Red Top Truck Stop
# 915        Mecca ( 92254 ) Mecca Travel Center ( Arco )
# 206           Salina , 84654 Cash Saver # 4 ( Chevron )
# 2273                Ukiah ( 95482 ) Jensen's Truck Stop
# 1483                    Oroville , 95965 Gold Nugget 76
#
#                                             clean_line2  \
# 873    5 619-661-1888 La Media & Airway ( S of CA 905 )
# 722               775-972-1653 US 395 ( at state line )
# 1579                  435-744-2211 UT 83 ( W of UT 13 )
# 1654                    4 602-269-8482 AZ 85 & 35th Ave
# 1103                  4 / 559-752-4905 US 99 & CA 190 W
# 2175       J 3559-665-7438 CA 152 & Rd 4 ( E of CA 59 )
# 915   6 760-396-5243 90480-66th Ave ( betw CA 86 & C...
# 206                        3 435-529-3362 US 50 & UT 24
# 2273                 1 707-467-9999 US 101 & N State St
# 1483               530-533-9093 CA 70 & Georgia Station
#
#                                    line3  Is_Unclear_OCR Address_Type
# 873                                   24           False        empty
# 722   <U+2610> <U+2610><U+2610> <U+2610>           False        empty
# 1579                          <U+2610> S           False        empty
# 1654                             24 XL D           False        empty
# 1103              <U+25A1> BS <U+2610> D           False        empty
# 2175                      484 S <U+2610>           False        empty
# 915                             111 ) 24           False        empty
# 206                  00 <U+2610><U+2610>           False        empty
# 2273                        24 MOD 24 22           False        empty
# 1483                               S 000           False        empty

# %%
#save df1 to Add_1_updated.csv
df1.to_csv('Add_2.csv', index=False)
#save df2 to Add_1_scraped_updated.csv
df2.to_csv('Add_2_scraped.csv', index=False)
