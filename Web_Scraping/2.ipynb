# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time

# Initialize list to store all data
all_data = []

# Loop through all states (1 to 65)
for state_id in range(1, 66):
    print(f"Processing state ID: {state_id}")
    
    # Read the webpage for current state
    url = f"https://www.truckstopsandservices.com/listcatbusinesses.php?id=19&state={state_id}"
    
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract state from h1 element
        h1_element = soup.find('h1', class_='h2')
        state = ""
        if h1_element:
            h1_text = h1_element.get_text(strip=True)
            # Extract state from "Truckers Directory - Truck Stops in STATE"
            if "Truck Stops in" in h1_text:
                state = h1_text.split("Truck Stops in")[-1].strip()
        
        # Find the tbody element with class "nohover"
        tbody = soup.find('tbody', class_='nohover')
        
        if tbody:
            # Find all anchor tags with href attributes
            anchor_tags = tbody.find_all('a', href=True)
            
            state_count = 0
            for anchor in anchor_tags:
                href = anchor['href']
                name = anchor.get_text(strip=True)
                
                # Only include links that match the pattern "location_details.php?id="
                if 'location_details.php?id=' in href:
                    all_data.append({
                        'state_id': state_id,
                        'state': state,
                        'name': name,
                        'href': href,
                        'full_url': f"https://www.truckstopsandservices.com/{href}",
                        'stop_type': 'Trucker'
                    })
                    state_count += 1
            
            print(f"  State: {state} - Found {state_count} locations")
        else:
            print(f"  State ID {state_id}: No data found")
            
    except Exception as e:
        print(f"  Error processing state ID {state_id}: {str(e)}")
    
    # Add small delay to be respectful to the server
    time.sleep(0.5)

# Create final DataFrame
df = pd.DataFrame(all_data)

print(f"\nTotal locations found across all states: {len(df)}")
print(f"Number of states with data: {df['state'].nunique()}")
print("\nFirst 10 results:")
print(df.head(10))
# Out:
# Processing state ID: 1
#   State: Alabama - Found 208 locations
#   State: Alabama - Found 208 locations
# Processing state ID: 2
# Processing state ID: 2
#   State: Arkansas - Found 160 locations
#   State: Arkansas - Found 160 locations
# Processing state ID: 3
# Processing state ID: 3
#   State: Arizona - Found 103 locations
#   State: Arizona - Found 103 locations
# Processing state ID: 4
# Processing state ID: 4
#   State: British Columbia - Found 46 locations
#   State: British Columbia - Found 46 locations
# Processing state ID: 5
# Processing state ID: 5
#   State: California - Found 235 locations
#   State: California - Found 235 locations
# Processing state ID: 6
# Processing state ID: 6
#   State: Colorado - Found 102 locations
#   State: Colorado - Found 102 locations
# Processing state ID: 7
# Processing state ID: 7
#   State: Connecticut - Found 27 locations
#   State: Connecticut - Found 27 locations
# Processing state ID: 8
# Processing state ID: 8
#   State: Delaware - Found 16 locations
#   State: Delaware - Found 16 locations
# Processing state ID: 9
# Processing state ID: 9
#   State: Florida - Found 195 locations
#   State: Florida - Found 195 locations
# Processing state ID: 10
# Processing state ID: 10
#   State: Georgia - Found 304 locations
#   State: Georgia - Found 304 locations
# Processing state ID: 11
# Processing state ID: 11
#   State: Iowa - Found 194 locations
#   State: Iowa - Found 194 locations
# Processing state ID: 12
# Processing state ID: 12
#   State: Idaho - Found 78 locations
#   State: Idaho - Found 78 locations
# Processing state ID: 13
# Processing state ID: 13
#   State: Illinois - Found 328 locations
#   State: Illinois - Found 328 locations
# Processing state ID: 14
# Processing state ID: 14
#   State: Indiana - Found 223 locations
#   State: Indiana - Found 223 locations
# Processing state ID: 15
# Processing state ID: 15
#   State: Kansas - Found 140 locations
#   State: Kansas - Found 140 locations
# Processing state ID: 16
# Processing state ID: 16
#   State: Kentucky - Found 139 locations
#   State: Kentucky - Found 139 locations
# Processing state ID: 17
# Processing state ID: 17
#   State: Louisiana - Found 248 locations
#   State: Louisiana - Found 248 locations
# Processing state ID: 18
# Processing state ID: 18
#   State: Massachusetts - Found 43 locations
#   State: Massachusetts - Found 43 locations
# Processing state ID: 19
# Processing state ID: 19
#   State: Maryland - Found 53 locations
#   State: Maryland - Found 53 locations
# Processing state ID: 20
# Processing state ID: 20
#   State: Maine - Found 37 locations
#   State: Maine - Found 37 locations
# Processing state ID: 21
# Processing state ID: 21
#   State: Michigan - Found 272 locations
#   State: Michigan - Found 272 locations
# Processing state ID: 22
# Processing state ID: 22
#   State: Minnesota - Found 165 locations
#   State: Minnesota - Found 165 locations
# Processing state ID: 23
# Processing state ID: 23
#   State: Missouri - Found 221 locations
#   State: Missouri - Found 221 locations
# Processing state ID: 24
# Processing state ID: 24
#   State: Mississippi - Found 169 locations
#   State: Mississippi - Found 169 locations
# Processing state ID: 25
# Processing state ID: 25
#   State: Montana - Found 73 locations
#   State: Montana - Found 73 locations
# Processing state ID: 26
# Processing state ID: 26
#   State: North Carolina - Found 235 locations
#   State: North Carolina - Found 235 locations
# Processing state ID: 27
# Processing state ID: 27
#   State: North Dakota - Found 72 locations
#   State: North Dakota - Found 72 locations
# Processing state ID: 28
# Processing state ID: 28
#   State: Nebraska - Found 111 locations
#   State: Nebraska - Found 111 locations
# Processing state ID: 29
# Processing state ID: 29
#   State: New Hampshire - Found 27 locations
#   State: New Hampshire - Found 27 locations
# Processing state ID: 30
# Processing state ID: 30
#   State: New Jersey - Found 108 locations
#   State: New Jersey - Found 108 locations
# Processing state ID: 31
# Processing state ID: 31
#   State: New Mexico - Found 98 locations
#   State: New Mexico - Found 98 locations
# Processing state ID: 32
# Processing state ID: 32
#   State: Nova Scotia - Found 8 locations
#   State: Nova Scotia - Found 8 locations
# Processing state ID: 33
# Processing state ID: 33
#   State: Nevada - Found 60 locations
#   State: Nevada - Found 60 locations
# Processing state ID: 34
# Processing state ID: 34
#   State: New York - Found 163 locations
#   State: New York - Found 163 locations
# Processing state ID: 35
# Processing state ID: 35
#   State: Ohio - Found 273 locations
#   State: Ohio - Found 273 locations
# Processing state ID: 36
# Processing state ID: 36
#   State: Oklahoma - Found 207 locations
#   State: Oklahoma - Found 207 locations
# Processing state ID: 37
# Processing state ID: 37
#   State: Ontario - Found 103 locations
#   State: Ontario - Found 103 locations
# Processing state ID: 38
# Processing state ID: 38
#   State: Oregon - Found 64 locations
#   State: Oregon - Found 64 locations
# Processing state ID: 39
# Processing state ID: 39
#   State: Pennsylvania - Found 255 locations
#   State: Pennsylvania - Found 255 locations
# Processing state ID: 40
# Processing state ID: 40
#   State: Quebec - Found 45 locations
#   State: Quebec - Found 45 locations
# Processing state ID: 41
# Processing state ID: 41
#   State: Rhode Island - Found 4 locations
#   State: Rhode Island - Found 4 locations
# Processing state ID: 42
# Processing state ID: 42
#   State: South Carolina - Found 202 locations
#   State: South Carolina - Found 202 locations
# Processing state ID: 43
# Processing state ID: 43
#   State: South Dakota - Found 82 locations
#   State: South Dakota - Found 82 locations
# Processing state ID: 44
# Processing state ID: 44
#   State: Tennessee - Found 191 locations
#   State: Tennessee - Found 191 locations
# Processing state ID: 45
# Processing state ID: 45
#   State: Texas - Found 878 locations
#   State: Texas - Found 878 locations
# Processing state ID: 46
# Processing state ID: 46
#   State: Utah - Found 87 locations
#   State: Utah - Found 87 locations
# Processing state ID: 47
# Processing state ID: 47
#   State: Virginia - Found 164 locations
#   State: Virginia - Found 164 locations
# Processing state ID: 48
# Processing state ID: 48
#   State: Vermont - Found 24 locations
#   State: Vermont - Found 24 locations
# Processing state ID: 49
# Processing state ID: 49
#   State: Wisconsin - Found 328 locations
#   State: Wisconsin - Found 328 locations
# Processing state ID: 50
# Processing state ID: 50
#   State: West Virginia - Found 42 locations
#   State: West Virginia - Found 42 locations
# Processing state ID: 51
# Processing state ID: 51
#   State: Washington - Found 69 locations
#   State: Washington - Found 69 locations
# Processing state ID: 52
# Processing state ID: 52
#   State: Wyoming - Found 76 locations
#   State: Wyoming - Found 76 locations
# Processing state ID: 53
# Processing state ID: 53
#   State: Alberta - Found 75 locations
#   State: Alberta - Found 75 locations
# Processing state ID: 54
# Processing state ID: 54
#   State: Manitoba - Found 14 locations
#   State: Manitoba - Found 14 locations
# Processing state ID: 55
# Processing state ID: 55
#   State: New Brunswick - Found 16 locations
#   State: New Brunswick - Found 16 locations
# Processing state ID: 56
# Processing state ID: 56
#   State: Newfoundland and Labrador - Found 9 locations
#   State: Newfoundland and Labrador - Found 9 locations
# Processing state ID: 57
# Processing state ID: 57
#   State ID 57: No data found
#   State ID 57: No data found
# Processing state ID: 58
# Processing state ID: 58
#   State ID 58: No data found
#   State ID 58: No data found
# Processing state ID: 59
# Processing state ID: 59
#   State ID 59: No data found
#   State ID 59: No data found
# Processing state ID: 60
# Processing state ID: 60
#   State ID 60: No data found
#   State ID 60: No data found
# Processing state ID: 61
# Processing state ID: 61
#   State: Saskatchewan - Found 31 locations
#   State: Saskatchewan - Found 31 locations
# Processing state ID: 62
# Processing state ID: 62
#   State: Yukon - Found 7 locations
#   State: Yukon - Found 7 locations
# Processing state ID: 63
# Processing state ID: 63
#   State: Alaska - Found 21 locations
#   State: Alaska - Found 21 locations
# Processing state ID: 64
# Processing state ID: 64
#   State ID 64: No data found
#   State ID 64: No data found
# Processing state ID: 65
# Processing state ID: 65
#   State ID 65: No data found
#   State ID 65: No data found
#
# Total locations found across all states: 7928
# Number of states with data: 59
#
# First 10 results:
#    state_id    state                        name  \
# 0         1  Alabama            205 TRUCK CENTER
# 1         1  Alabama               231 FUEL STOP
# 2         1  Alabama            4 WAY QUICK STOP
# 3         1  Alabama  A. W. HERNDON OIL CO. INC.
# 4         1  Alabama        ALLEN'S FOOD MART #9
# 5         1  Alabama         ARNOLD'S TRUCK STOP
# 6         1  Alabama              BOAZ FOOD MART
# 7         1  Alabama            BOLIGEE ONE STOP
# 8         1  Alabama                          BP
# 9         1  Alabama  BROOKWOOD SHELL TRUCK STOP
#
#                             href  \
# 0    location_details.php?id=171
# 1  location_details.php?id=53886
# 2  location_details.php?id=53890
# 3  location_details.php?id=54388
# 4  location_details.php?id=10176
# 5  location_details.php?id=10085
# 6  location_details.php?id=18449
# 7    location_details.php?id=392
# 8  location_details.php?id=53994
# 9    location_details.php?id=446
#
#                                             full_url stop_type
# 0  https://www.truckstopsandservices.com/location...   Trucker
# 1  https://www.truckstopsandservices.com/location...   Trucker
# 2  https://www.truckstopsandservices.com/location...   Trucker
# 3  https://www.truckstopsandservices.com/location...   Trucker
# 4  https://www.truckstopsandservices.com/location...   Trucker
# 5  https://www.truckstopsandservices.com/location...   Trucker
# 6  https://www.truckstopsandservices.com/location...   Trucker
# 7  https://www.truckstopsandservices.com/location...   Trucker
# 8  https://www.truckstopsandservices.com/location...   Trucker
# 9  https://www.truckstopsandservices.com/location...   Trucker
#
# Total locations found across all states: 7928
# Number of states with data: 59
#
# First 10 results:
#    state_id    state                        name  \
# 0         1  Alabama            205 TRUCK CENTER
# 1         1  Alabama               231 FUEL STOP
# 2         1  Alabama            4 WAY QUICK STOP
# 3         1  Alabama  A. W. HERNDON OIL CO. INC.
# 4         1  Alabama        ALLEN'S FOOD MART #9
# 5         1  Alabama         ARNOLD'S TRUCK STOP
# 6         1  Alabama              BOAZ FOOD MART
# 7         1  Alabama            BOLIGEE ONE STOP
# 8         1  Alabama                          BP
# 9         1  Alabama  BROOKWOOD SHELL TRUCK STOP
#
#                             href  \
# 0    location_details.php?id=171
# 1  location_details.php?id=53886
# 2  location_details.php?id=53890
# 3  location_details.php?id=54388
# 4  location_details.php?id=10176
# 5  location_details.php?id=10085
# 6  location_details.php?id=18449
# 7    location_details.php?id=392
# 8  location_details.php?id=53994
# 9    location_details.php?id=446
#
#                                             full_url stop_type
# 0  https://www.truckstopsandservices.com/location...   Trucker
# 1  https://www.truckstopsandservices.com/location...   Trucker
# 2  https://www.truckstopsandservices.com/location...   Trucker
# 3  https://www.truckstopsandservices.com/location...   Trucker
# 4  https://www.truckstopsandservices.com/location...   Trucker
# 5  https://www.truckstopsandservices.com/location...   Trucker
# 6  https://www.truckstopsandservices.com/location...   Trucker
# 7  https://www.truckstopsandservices.com/location...   Trucker
# 8  https://www.truckstopsandservices.com/location...   Trucker
# 9  https://www.truckstopsandservices.com/location...   Trucker

# %%
# Show some statistics
print("\n=== SUMMARY STATISTICS ===")
print(f"Total truck stops found: {len(df)}")
print(f"Number of unique states: {df['state'].nunique()}")
print(f"State IDs processed: {df['state_id'].min()} to {df['state_id'].max()}")

# Show counts by state
print("\nTruck stops per state:")
state_counts = df.groupby(['state_id', 'state']).size().reset_index(name='count')
state_counts = state_counts.sort_values('count', ascending=False)
print(state_counts)
# Out:
# === SUMMARY STATISTICS ===
# Total truck stops found: 7928
# Number of unique states: 59
# State IDs processed: 1 to 63
#
# Truck stops per state:
#     state_id                      state  count
# 44        45                      Texas    878
# 48        49                  Wisconsin    328
# 12        13                   Illinois    328
# 9         10                    Georgia    304
# 34        35                       Ohio    273
# 20        21                   Michigan    272
# 38        39               Pennsylvania    255
# 16        17                  Louisiana    248
# 25        26             North Carolina    235
# 4          5                 California    235
# 13        14                    Indiana    223
# 22        23                   Missouri    221
# 0          1                    Alabama    208
# 35        36                   Oklahoma    207
# 41        42             South Carolina    202
# 8          9                    Florida    195
# 10        11                       Iowa    194
# 43        44                  Tennessee    191
# 23        24                Mississippi    169
# 21        22                  Minnesota    165
# 46        47                   Virginia    164
# 33        34                   New York    163
# 1          2                   Arkansas    160
# 14        15                     Kansas    140
# 15        16                   Kentucky    139
# 27        28                   Nebraska    111
# 29        30                 New Jersey    108
# 2          3                    Arizona    103
# 36        37                    Ontario    103
# 5          6                   Colorado    102
# 30        31                 New Mexico     98
# 45        46                       Utah     87
# 42        43               South Dakota     82
# 11        12                      Idaho     78
# 51        52                    Wyoming     76
# 52        53                    Alberta     75
# 24        25                    Montana     73
# 26        27               North Dakota     72
# 50        51                 Washington     69
# 37        38                     Oregon     64
# 32        33                     Nevada     60
# 18        19                   Maryland     53
# 3          4           British Columbia     46
# 39        40                     Quebec     45
# 17        18              Massachusetts     43
# 49        50              West Virginia     42
# 19        20                      Maine     37
# 56        61               Saskatchewan     31
# 6          7                Connecticut     27
# 28        29              New Hampshire     27
# 47        48                    Vermont     24
# 58        63                     Alaska     21
# 7          8                   Delaware     16
# 54        55              New Brunswick     16
# 53        54                   Manitoba     14
# 55        56  Newfoundland and Labrador      9
# 31        32                Nova Scotia      8
# 57        62                      Yukon      7
# 40        41               Rhode Island      4

# %%
# Explore the data further
print("Top 10 states with most truck stops:")
top_states = df['state'].value_counts().head(10)
print(top_states)

print("\nSample of truck stop names:")
print(df['name'].head(15).tolist())

# Check for any missing data
print("\nData quality check:")
print(f"Missing state names: {df['state'].isna().sum()}")
print(f"Missing truck stop names: {df['name'].isna().sum()}")
print(f"Empty state names: {(df['state'] == '').sum()}")

# Show DataFrame info
print("\nDataFrame info:")
print(df.info())
# Out:
# Top 10 states with most truck stops:
# state
# Texas             878
# Wisconsin         328
# Illinois          328
# Georgia           304
# Ohio              273
# Michigan          272
# Pennsylvania      255
# Louisiana         248
# North Carolina    235
# California        235
# Name: count, dtype: int64
#
# Sample of truck stop names:
# ['205 TRUCK CENTER', '231 FUEL STOP', '4 WAY QUICK STOP', 'A. W. HERNDON OIL CO. INC.', "ALLEN'S FOOD MART #9", "ARNOLD'S TRUCK STOP", 'BOAZ FOOD MART', 'BOLIGEE ONE STOP', 'BP', 'BROOKWOOD SHELL TRUCK STOP', 'CAFFEE JUNCTION CHEVRON', 'CEFCO #0485', 'CHEVRON', 'CHICASAW CORNER STOP', 'CIRCLE K']
#
# Data quality check:
# Missing state names: 0
# Missing truck stop names: 0
# Empty state names: 0
#
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7928 entries, 0 to 7927
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   state_id   7928 non-null   int64
#  1   state      7928 non-null   object
#  2   name       7928 non-null   object
#  3   href       7928 non-null   object
#  4   full_url   7928 non-null   object
#  5   stop_type  7928 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 371.8+ KB
# None

# %%
df
# Out:
#       state_id    state                        name  \
# 0            1  Alabama            205 TRUCK CENTER
# 1            1  Alabama               231 FUEL STOP
# 2            1  Alabama            4 WAY QUICK STOP
# 3            1  Alabama  A. W. HERNDON OIL CO. INC.
# 4            1  Alabama        ALLEN'S FOOD MART #9
# ...        ...      ...                         ...
# 7923        63   Alaska              MENTASTA LODGE
# 7924        63   Alaska       NORTHERN ENERGY CORP.
# 7925        63   Alaska           TESORO NORTH  #78
# 7926        63   Alaska      TESORO TRUCK STOP #101
# 7927        63   Alaska     YOUNG'S CHEVRON SERVICE
#
#                                href  \
# 0       location_details.php?id=171
# 1     location_details.php?id=53886
# 2     location_details.php?id=53890
# 3     location_details.php?id=54388
# 4     location_details.php?id=10176
# ...                             ...
# 7923  location_details.php?id=54692
# 7924  location_details.php?id=22842
# 7925  location_details.php?id=22840
# 7926  location_details.php?id=22818
# 7927  location_details.php?id=22843
#
#                                                full_url stop_type
# 0     https://www.truckstopsandservices.com/location...   Trucker
# 1     https://www.truckstopsandservices.com/location...   Trucker
# 2     https://www.truckstopsandservices.com/location...   Trucker
# 3     https://www.truckstopsandservices.com/location...   Trucker
# 4     https://www.truckstopsandservices.com/location...   Trucker
# ...                                                 ...       ...
# 7923  https://www.truckstopsandservices.com/location...   Trucker
# 7924  https://www.truckstopsandservices.com/location...   Trucker
# 7925  https://www.truckstopsandservices.com/location...   Trucker
# 7926  https://www.truckstopsandservices.com/location...   Trucker
# 7927  https://www.truckstopsandservices.com/location...   Trucker
#
# [7928 rows x 6 columns]

# %%
# Now scrape RV stops from rvandtravelers.com
print("\n=== STARTING RV STOPS SCRAPING ===")

# Loop through all states (1 to 65) for RV stops
for state_id in range(1, 66):
    print(f"Processing RV stops for state ID: {state_id}")
    
    # Read the webpage for current state (RV site)
    url = f"http://www.rvandtravelers.com/listcatbusinesses.php?id=19&state={state_id}"
    
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Extract state from h1 element
        h1_element = soup.find('h1', class_='h2')
        state = ""
        if h1_element:
            h1_text = h1_element.get_text(strip=True)
            # Extract state from title (may have different format)
            if "in" in h1_text:
                # Try to extract state from various possible formats
                parts = h1_text.split("in")
                if len(parts) > 1:
                    state = parts[-1].strip()
        
        # Find the tbody element with class "nohover"
        tbody = soup.find('tbody', class_='nohover')
        
        if tbody:
            # Find all anchor tags with href attributes
            anchor_tags = tbody.find_all('a', href=True)
            
            state_count = 0
            for anchor in anchor_tags:
                href = anchor['href']
                name = anchor.get_text(strip=True)
                
                # Only include links that match the pattern "location_details.php?id="
                if 'location_details.php?id=' in href:
                    all_data.append({
                        'state_id': state_id,
                        'state': state,
                        'name': name,
                        'href': href,
                        'full_url': f"http://www.rvandtravelers.com/{href}",
                        'stop_type': 'RVer'
                    })
                    state_count += 1
            
            print(f"  State: {state} - Found {state_count} RV locations")
        else:
            print(f"  State ID {state_id}: No RV data found")
            
    except Exception as e:
        print(f"  Error processing RV state ID {state_id}: {str(e)}")
    
    # Add small delay to be respectful to the server
    time.sleep(0.5)

# Create updated DataFrame with both Trucker and RVer data
df_combined = pd.DataFrame(all_data)

print(f"\n=== COMBINED RESULTS ===")
print(f"Total locations found (Trucker + RVer): {len(df_combined)}")
print(f"Number of states with data: {df_combined['state'].nunique()}")

# Show breakdown by stop type
print("\nBreakdown by stop type:")
stop_type_counts = df_combined['stop_type'].value_counts()
print(stop_type_counts)

# Save the combined data to CSV
df_combined.to_csv('2.csv', index=False)
print(f"\nData saved to '2.csv'")
print(f"Total records saved: {len(df_combined)}")
# Out:
# === STARTING RV STOPS SCRAPING ===
# Processing RV stops for state ID: 1
#   State: Alabama - Found 200 RV locations
#   State: Alabama - Found 200 RV locations
# Processing RV stops for state ID: 2
# Processing RV stops for state ID: 2
#   State: Arkansas - Found 154 RV locations
#   State: Arkansas - Found 154 RV locations
# Processing RV stops for state ID: 3
# Processing RV stops for state ID: 3
#   State: Arizona - Found 89 RV locations
#   State: Arizona - Found 89 RV locations
# Processing RV stops for state ID: 4
# Processing RV stops for state ID: 4
#   State: British Columbia - Found 47 RV locations
#   State: British Columbia - Found 47 RV locations
# Processing RV stops for state ID: 5
# Processing RV stops for state ID: 5
#   State: California - Found 220 RV locations
#   State: California - Found 220 RV locations
# Processing RV stops for state ID: 6
# Processing RV stops for state ID: 6
#   State: Colorado - Found 100 RV locations
#   State: Colorado - Found 100 RV locations
# Processing RV stops for state ID: 7
# Processing RV stops for state ID: 7
#   State: Connecticut - Found 26 RV locations
#   State: Connecticut - Found 26 RV locations
# Processing RV stops for state ID: 8
# Processing RV stops for state ID: 8
#   State: Delaware - Found 16 RV locations
#   State: Delaware - Found 16 RV locations
# Processing RV stops for state ID: 9
# Processing RV stops for state ID: 9
#   State: Florida - Found 181 RV locations
#   State: Florida - Found 181 RV locations
# Processing RV stops for state ID: 10
# Processing RV stops for state ID: 10
#   State: Georgia - Found 289 RV locations
#   State: Georgia - Found 289 RV locations
# Processing RV stops for state ID: 11
# Processing RV stops for state ID: 11
#   State: Iowa - Found 178 RV locations
#   State: Iowa - Found 178 RV locations
# Processing RV stops for state ID: 12
# Processing RV stops for state ID: 12
#   State: Idaho - Found 73 RV locations
#   State: Idaho - Found 73 RV locations
# Processing RV stops for state ID: 13
# Processing RV stops for state ID: 13
#   State: ois - Found 293 RV locations
#   State: ois - Found 293 RV locations
# Processing RV stops for state ID: 14
# Processing RV stops for state ID: 14
#   State: Indiana - Found 212 RV locations
#   State: Indiana - Found 212 RV locations
# Processing RV stops for state ID: 15
# Processing RV stops for state ID: 15
#   State: Kansas - Found 133 RV locations
#   State: Kansas - Found 133 RV locations
# Processing RV stops for state ID: 16
# Processing RV stops for state ID: 16
#   State: Kentucky - Found 130 RV locations
#   State: Kentucky - Found 130 RV locations
# Processing RV stops for state ID: 17
# Processing RV stops for state ID: 17
#   State: Louisiana - Found 244 RV locations
#   State: Louisiana - Found 244 RV locations
# Processing RV stops for state ID: 18
# Processing RV stops for state ID: 18
#   State: Massachusetts - Found 43 RV locations
#   State: Massachusetts - Found 43 RV locations
# Processing RV stops for state ID: 19
# Processing RV stops for state ID: 19
#   State: Maryland - Found 51 RV locations
#   State: Maryland - Found 51 RV locations
# Processing RV stops for state ID: 20
# Processing RV stops for state ID: 20
#   State: e - Found 36 RV locations
#   State: e - Found 36 RV locations
# Processing RV stops for state ID: 21
# Processing RV stops for state ID: 21
#   State: Michigan - Found 268 RV locations
#   State: Michigan - Found 268 RV locations
# Processing RV stops for state ID: 22
# Processing RV stops for state ID: 22
#   State: nesota - Found 163 RV locations
#   State: nesota - Found 163 RV locations
# Processing RV stops for state ID: 23
# Processing RV stops for state ID: 23
#   State: Missouri - Found 210 RV locations
#   State: Missouri - Found 210 RV locations
# Processing RV stops for state ID: 24
# Processing RV stops for state ID: 24
#   State: Mississippi - Found 164 RV locations
#   State: Mississippi - Found 164 RV locations
# Processing RV stops for state ID: 25
# Processing RV stops for state ID: 25
#   State: Montana - Found 70 RV locations
#   State: Montana - Found 70 RV locations
# Processing RV stops for state ID: 26
# Processing RV stops for state ID: 26
#   State: a - Found 221 RV locations
#   State: a - Found 221 RV locations
# Processing RV stops for state ID: 27
# Processing RV stops for state ID: 27
#   State: North Dakota - Found 72 RV locations
#   State: North Dakota - Found 72 RV locations
# Processing RV stops for state ID: 28
# Processing RV stops for state ID: 28
#   State: Nebraska - Found 110 RV locations
#   State: Nebraska - Found 110 RV locations
# Processing RV stops for state ID: 29
# Processing RV stops for state ID: 29
#   State: New Hampshire - Found 27 RV locations
#   State: New Hampshire - Found 27 RV locations
# Processing RV stops for state ID: 30
# Processing RV stops for state ID: 30
#   State: New Jersey - Found 110 RV locations
#   State: New Jersey - Found 110 RV locations
# Processing RV stops for state ID: 31
# Processing RV stops for state ID: 31
#   State: New Mexico - Found 94 RV locations
#   State: New Mexico - Found 94 RV locations
# Processing RV stops for state ID: 32
#   State: Nova Scotia - Found 8 RV locations
# Processing RV stops for state ID: 32
#   State: Nova Scotia - Found 8 RV locations
# Processing RV stops for state ID: 33
# Processing RV stops for state ID: 33
#   State: Nevada - Found 54 RV locations
#   State: Nevada - Found 54 RV locations
# Processing RV stops for state ID: 34
# Processing RV stops for state ID: 34
#   State: New York - Found 159 RV locations
#   State: New York - Found 159 RV locations
# Processing RV stops for state ID: 35
# Processing RV stops for state ID: 35
#   State: Ohio - Found 252 RV locations
#   State: Ohio - Found 252 RV locations
# Processing RV stops for state ID: 36
# Processing RV stops for state ID: 36
#   State: Oklahoma - Found 204 RV locations
#   State: Oklahoma - Found 204 RV locations
# Processing RV stops for state ID: 37
# Processing RV stops for state ID: 37
#   State: Ontario - Found 103 RV locations
#   State: Ontario - Found 103 RV locations
# Processing RV stops for state ID: 38
# Processing RV stops for state ID: 38
#   State: Oregon - Found 64 RV locations
#   State: Oregon - Found 64 RV locations
# Processing RV stops for state ID: 39
# Processing RV stops for state ID: 39
#   State: Pennsylvania - Found 235 RV locations
#   State: Pennsylvania - Found 235 RV locations
# Processing RV stops for state ID: 40
# Processing RV stops for state ID: 40
#   State: Quebec - Found 46 RV locations
#   State: Quebec - Found 46 RV locations
# Processing RV stops for state ID: 41
# Processing RV stops for state ID: 41
#   State: Rhode Island - Found 4 RV locations
#   State: Rhode Island - Found 4 RV locations
# Processing RV stops for state ID: 42
# Processing RV stops for state ID: 42
#   State: a - Found 190 RV locations
#   State: a - Found 190 RV locations
# Processing RV stops for state ID: 43
# Processing RV stops for state ID: 43
#   State: South Dakota - Found 81 RV locations
#   State: South Dakota - Found 81 RV locations
# Processing RV stops for state ID: 44
# Processing RV stops for state ID: 44
#   State: Tennessee - Found 184 RV locations
#   State: Tennessee - Found 184 RV locations
# Processing RV stops for state ID: 45
# Processing RV stops for state ID: 45
#   State: Texas - Found 834 RV locations
#   State: Texas - Found 834 RV locations
# Processing RV stops for state ID: 46
# Processing RV stops for state ID: 46
#   State: Utah - Found 88 RV locations
#   State: Utah - Found 88 RV locations
# Processing RV stops for state ID: 47
# Processing RV stops for state ID: 47
#   State: ia - Found 159 RV locations
#   State: ia - Found 159 RV locations
# Processing RV stops for state ID: 48
# Processing RV stops for state ID: 48
#   State: Vermont - Found 25 RV locations
#   State: Vermont - Found 25 RV locations
# Processing RV stops for state ID: 49
# Processing RV stops for state ID: 49
#   State:  - Found 321 RV locations
#   State:  - Found 321 RV locations
# Processing RV stops for state ID: 50
# Processing RV stops for state ID: 50
#   State: ia - Found 41 RV locations
#   State: ia - Found 41 RV locations
# Processing RV stops for state ID: 51
# Processing RV stops for state ID: 51
#   State: gton - Found 67 RV locations
#   State: gton - Found 67 RV locations
# Processing RV stops for state ID: 52
# Processing RV stops for state ID: 52
#   State: g - Found 78 RV locations
#   State: g - Found 78 RV locations
# Processing RV stops for state ID: 53
# Processing RV stops for state ID: 53
#   State: Alberta - Found 75 RV locations
#   State: Alberta - Found 75 RV locations
# Processing RV stops for state ID: 54
# Processing RV stops for state ID: 54
#   State: Manitoba - Found 16 RV locations
#   State: Manitoba - Found 16 RV locations
# Processing RV stops for state ID: 55
# Processing RV stops for state ID: 55
#   State: New Brunswick - Found 16 RV locations
#   State: New Brunswick - Found 16 RV locations
# Processing RV stops for state ID: 56
#   State: Newfoundland and Labrador - Found 9 RV locations
# Processing RV stops for state ID: 56
#   State: Newfoundland and Labrador - Found 9 RV locations
# Processing RV stops for state ID: 57
#   State ID 57: No RV data found
# Processing RV stops for state ID: 57
#   State ID 57: No RV data found
# Processing RV stops for state ID: 58
#   State ID 58: No RV data found
# Processing RV stops for state ID: 58
#   State ID 58: No RV data found
# Processing RV stops for state ID: 59
# Processing RV stops for state ID: 59
#   State ID 59: No RV data found
#   State ID 59: No RV data found
# Processing RV stops for state ID: 60
#   State ID 60: No RV data found
# Processing RV stops for state ID: 60
#   State ID 60: No RV data found
# Processing RV stops for state ID: 61
# Processing RV stops for state ID: 61
#   State: Saskatchewan - Found 31 RV locations
#   State: Saskatchewan - Found 31 RV locations
# Processing RV stops for state ID: 62
# Processing RV stops for state ID: 62
#   State: Yukon - Found 8 RV locations
#   State: Yukon - Found 8 RV locations
# Processing RV stops for state ID: 63
# Processing RV stops for state ID: 63
#   State: Alaska - Found 22 RV locations
#   State: Alaska - Found 22 RV locations
# Processing RV stops for state ID: 64
#   State ID 64: No RV data found
# Processing RV stops for state ID: 64
#   State ID 64: No RV data found
# Processing RV stops for state ID: 65
#   State ID 65: No RV data found
# Processing RV stops for state ID: 65
#   State ID 65: No RV data found
#
# === COMBINED RESULTS ===
# Total locations found (Trucker + RVer): 15526
# Number of states with data: 67
#
# Breakdown by stop type:
# stop_type
# Trucker    7928
# RVer       7598
# Name: count, dtype: int64
#
# Data saved to '2.csv'
# Total records saved: 15526
#
# === COMBINED RESULTS ===
# Total locations found (Trucker + RVer): 15526
# Number of states with data: 67
#
# Breakdown by stop type:
# stop_type
# Trucker    7928
# RVer       7598
# Name: count, dtype: int64
#
# Data saved to '2.csv'
# Total records saved: 15526
