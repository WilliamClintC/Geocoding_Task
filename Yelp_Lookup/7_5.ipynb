# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ast

# %%
df = pd.read_csv(r'C:\Users\clint\Desktop\Geocoding_Task\Yelp_Lookup\6.csv')
df
# Out:
#                                           clean_line1  \
# 0              Coalville , 84017 Holiday Hills ( 66 )
# 1                      Coalville , 84017 Hills ( 66 )
# 2          D Coalville , 84017 Holiday Hills ( 66 ) )
# 3          D Coalville ( 84017 ) Holiday Hills ( 66 )
# 4          D Coalville ( 84017 ) Holiday Hills ( 66 )
# ...                                               ...
# 2328       Corning ( 96021 ) Love's Travel Stop # 410
# 2329          , 96021 Flying J Travel Plaza # 0510154
# 2330  Corning , 96021 Flying J Travel Plaza # 0510154
# 2331       A Grenada ( 96038 ) 3 J's Food Mart ( 76 )
# 2332  A Grenada ( 96038 ) 3 J's Food Mart ( 76 ) Dr )
#
#                                             clean_line2  \
# 0                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 1         435-336-4421 I-80 Holiday Exit 162 ( UT 280 )
# 2               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# 3                 435-336-4421 I-80 Exit 162 ( UT 280 )
# ...

# %%
# Move row 1588 to just before row 1585
# First, extract the row we want to move
row_to_move = df.iloc[1588:1589].copy()
row_to_move
# Out:
#                                    clean_line1  \
# 1588  Plymouth , 84330 Fast - Stop ( Chevron )
#
#                                   clean_line2 line3      city  zip_code  \
# 1588  435-458-3816 I-15 Exit 392 ( Nucor Rd )   NaN  Plymouth     84330
#
#                         label         phone  year major_city state  ...  \
# 1588  Fast - Stop ( Chevron )  435-458-3816  2006   Plymouth    UT  ...
#
#                    State_scraped_matches_row_ids_parsed  \
# 1588  [398, 399, 400, 401, 402, 403, 404, 405, 406, ...
#
#      City_scraped_matches_row_ids_parsed Exit_scraped_matches_row_ids_parsed  \
# 1588                          [482, 933]                          [482, 933]
#
#                     Road_scraped_matches_row_ids_parsed  \
# 1588  [16, 125, 156, 163, 168, 184, 205, 222, 229, 2...
#
#                    Label_scraped_matches_row_ids_parsed  \
# 1588  [11, 12, 24, 25, 28, 30, 34, 35, 36, 37, 38, 3...
#
#                    Chain_scraped_matches_row_ids_parsed  \
# ...

# %%
# Remove the row from its original position
df_temp = df.drop(df.index[1588]).reset_index(drop=True)

# Insert the row at the new position (before what will be row 1585 after the removal)
# Since we removed one row, the target position is now 1585
df = pd.concat([
    df_temp.iloc[:1585],  # All rows before position 1585
    row_to_move.reset_index(drop=True),  # The row we're moving
    df_temp.iloc[1585:]   # All rows from position 1585 onwards
], ignore_index=True)

print("Row movement completed!")
print(f"DataFrame shape: {df.shape}")

# Display rows around the moved position to verify
print("\nRows around the moved position (1585-1587):")
df.iloc[1584:1588]
# Out:
# Row movement completed!
# DataFrame shape: (2333, 47)
#
# Rows around the moved position (1585-1587):
#                                      clean_line1  \
# 1584            Logan ( 84321 ) Thomas Petroleum
# 1585    Plymouth , 84330 Fast - Stop ( Chevron )
# 1586  B Plymouth , 84330 Fast - Stop ( Chevron )
# 1587    Plymouth , 84330 Fast - Stop ( Chevron )
#
#                                   clean_line2 line3      city  zip_code  \
# 1584       435-753-4930 1070 UT 30 W & UT 252   NaN     Logan     84321
# 1585  435-458-3816 I-15 Exit 392 ( Nucor Rd )   NaN  Plymouth     84330
# 1586  435-458-3634 I-15 Exit 392 ( Nucor Rd )   S S  Plymouth     84330
# 1587  435-458-3634 I-15 Exit 392 ( Nucor Rd )     S  Plymouth     84330
#
#                         label         phone  year major_city state  ...  \
# 1584         Thomas Petroleum  435-753-4930  2016      Logan    UT  ...
# 1585  Fast - Stop ( Chevron )  435-458-3816  2006   Plymouth    UT  ...
# ...

# %%
df
# Out:
#                                           clean_line1  \
# 0              Coalville , 84017 Holiday Hills ( 66 )
# 1                      Coalville , 84017 Hills ( 66 )
# 2          D Coalville , 84017 Holiday Hills ( 66 ) )
# 3          D Coalville ( 84017 ) Holiday Hills ( 66 )
# 4          D Coalville ( 84017 ) Holiday Hills ( 66 )
# ...                                               ...
# 2328       Corning ( 96021 ) Love's Travel Stop # 410
# 2329          , 96021 Flying J Travel Plaza # 0510154
# 2330  Corning , 96021 Flying J Travel Plaza # 0510154
# 2331       A Grenada ( 96038 ) 3 J's Food Mart ( 76 )
# 2332  A Grenada ( 96038 ) 3 J's Food Mart ( 76 ) Dr )
#
#                                             clean_line2  \
# 0                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 1         435-336-4421 I-80 Holiday Exit 162 ( UT 280 )
# 2               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# 3                 435-336-4421 I-80 Exit 162 ( UT 280 )
# ...

# %%
# save 7_5.csv
df.to_csv(r'7_5.csv', index=False)
