# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\clint\Desktop\Geocoding_Task\Matching_WebScrape\6.csv')
#filter df for only flagged rows
# df = df[df['Flag_Reason'] == "No matches found"]
# #filter for Adress_Type != 'Proper'
# df = df[df['Address_Type']  == 'Exit']
#filter for OCR_state in #filter for states CA, UT, NV, AZ
df = df[df['OCR_state'].isin(['CA', 'UT', 'NV', 'AZ'])]
df
# Out:
# C:\Users\clint\AppData\Local\Temp\ipykernel_24852\3415193844.py:3: DtypeWarning: Columns (19,36,53,57,72,74,77,86,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\clint\Desktop\Geocoding_Task\Matching_WebScrape\6.csv')
#        OCR_Unnamed: 0                 OCR_filename  OCR_record_num  \
# 43950           23197  RVersFriend2006-115-ocr.csv              18
# 43951           23197  RVersFriend2006-115-ocr.csv              18
# 43952           23198  RVersFriend2007-104-ocr.csv               7
# 43953           23198  RVersFriend2007-104-ocr.csv               7
# 43954           23199     TF2008_258_271-0-ocr.csv               7
# ...               ...                          ...             ...
# 81401           37887     TF2016_020_035-4-ocr.csv              38
# 81402           37894     TF2015_018_031-6-ocr.csv              27
# 81403           37894     TF2015_018_031-6-ocr.csv              27
# 81404           37895     TF2016_020_035-5-ocr.csv              27
# 81405           37895     TF2016_020_035-5-ocr.csv              27
#
#                                          OCR_clean_line1  \
# 43950             Coalville , 84017 Holiday Hills ( 66 )
# 43951             Coalville , 84017 Holiday Hills ( 66 )
# 43952                     Coalville , 84017 Hills ( 66 )
# 43953                     Coalville , 84017 Hills ( 66 )
# 43954         D Coalville , 84017 Holiday Hills ( 66 ) )
# ...                                                  ...
# 81401  D Sacramento ( West ) ( 95691 ) 1-80 Harbor Bu...
# 81402  D Yuba City ( 95991 ) 4142 Dhami's CA Truck 99...
# 81403  D Yuba City ( 95991 ) 4142 Dhami's CA Truck 99...
# 81404  Yuba City ( 95991 ) Dhami's Truck Stop S ( of ...
# 81405  Yuba City ( 95991 ) Dhami's Truck Stop S ( of ...
#
#                                      OCR_clean_line2  \
# 43950          435-336-4421 1-80 Exit 162 ( UT 280 )
# 43951          435-336-4421 1-80 Exit 162 ( UT 280 )
# 43952  435-336-4421 1-80 Holiday Exit 162 ( UT 280 )
# 43953  435-336-4421 1-80 Holiday Exit 162 ( UT 280 )
# 43954        4 435-336-4421 1-80 Exit 162 ( UT 280 )
# ...                                              ...
# 81401                             916-372-2893 Pilot
# 81402       530-755-4564 CA 99 & Obanion ( 10 mi S )
# 81403       530-755-4564 CA 99 & Obanion ( 10 mi S )
# 81404       530-755-4564 CA 99 & Obanion ( 10 mi S )
# 81405       530-755-4564 CA 99 & Obanion ( 10 mi S )
#
#                           OCR_line3    OCR_city  OCR_zip_code  \
# 43950                            MO   Coalville         84017
# 43951                            MO   Coalville         84017
# 43952                    M <U+25A1>   Coalville         84017
# 43953                    M <U+25A1>   Coalville         84017
# 43954  M <U+2610> <U+2610> <U+2610>   Coalville         84017
# ...                             ...         ...           ...
# 81401                 ) 24 <U+2610>  Sacramento         95691
# 81402                           M D   Yuba City         95991
# 81403                           M D   Yuba City         95991
# 81404                    M <U+25A1>   Yuba City         95991
# 81405                    M <U+25A1>   Yuba City         95991
#
#                                                OCR_label     OCR_phone  ...  \
# 43950                               Holiday Hills ( 66 )  435-336-4421  ...
# 43951                               Holiday Hills ( 66 )  435-336-4421  ...
# 43952                                       Hills ( 66 )  435-336-4421  ...
# 43953                                       Hills ( 66 )  435-336-4421  ...
# 43954                             Holiday Hills ( 66 ) )  435-336-4421  ...
# ...                                                  ...           ...  ...
# 81401  1-80 Harbor Bus Truck / US & 50 Auto Xt 1 Stop...  916-372-2893  ...
# 81402  4142 Dhami's CA Truck 99 ( 5 Stop mi S ( of Sh...  530-755-4564  ...
# 81403  4142 Dhami's CA Truck 99 ( 5 Stop mi S ( of Sh...  530-755-4564  ...
# 81404           Dhami's Truck Stop S ( of Shell town ) )  530-755-4564  ...
# 81405           Dhami's Truck Stop S ( of Shell town ) )  530-755-4564  ...
#
#       OCR_address_standardized_ON_parenthesis  \
# 43950                              ( UT 280 )
# 43951                              ( UT 280 )
# 43952                              ( UT 280 )
# 43953                              ( UT 280 )
# 43954                              ( UT 280 )
# ...                                       ...
# 81401                                     NaN
# 81402                             ( 10 mi S )
# 81403                             ( 10 mi S )
# 81404                             ( 10 mi S )
# 81405                             ( 10 mi S )
#
#       OCR_address_standardized_OFF_parenthesis OCR_Address_Type  \
# 43950                           I-80 Exit 162              Exit
# 43951                           I-80 Exit 162              Exit
# 43952                   I-80 Holiday Exit 162              Exit
# 43953                   I-80 Holiday Exit 162              Exit
# 43954                           I-80 Exit 162              Exit
# ...                                        ...              ...
# 81401                                    Pilot            empty
# 81402                          CA 99 & Obanion            empty
# 81403                          CA 99 & Obanion            empty
# 81404                          CA 99 & Obanion            empty
# 81405                          CA 99 & Obanion            empty
#
#       OCR_Exit_Number  Exit_From_Address  Exit_From_Label Is_Unclear_OCR  \
# 43950             162                162              NaN          False
# 43951             162                162              NaN          False
# 43952             162                162              NaN          False
# 43953             162                162              NaN          False
# 43954             162                162              NaN          False
# ...               ...                ...              ...            ...
# 81401             NaN                NaN              NaN          False
# 81402             NaN                NaN              NaN          False
# 81403             NaN                NaN              NaN          False
# 81404             NaN                NaN              NaN          False
# 81405             NaN                NaN              NaN          False
#
#       OCR_Main_Road OCR_Secondary_Road  Manually Verified?
# 43950          I-80                NaN                  No
# 43951          I-80                NaN                  No
# 43952          I-80                NaN                  No
# 43953          I-80                NaN                  No
# 43954          I-80                NaN                  No
# ...             ...                ...                 ...
# 81401         Pilot                NaN  Please Verify This
# 81402         CA 99            Obanion  Please Verify This
# 81403         CA 99            Obanion  Please Verify This
# 81404         CA 99            Obanion  Please Verify This
# 81405         CA 99            Obanion  Please Verify This
#
# [4610 rows x 93 columns]

# %%
#display     'OCR_Address_Type','OCR_zip_code', 'OCR_label', 'OCR_phone', 'OCR_address_standardized', 
    # 'OCR_state', 'OCR_chain', 'OCR_city_standardized', 'Flagged', 'Flag_Reason',
    # 'OCR_address_standardized_ON_parenthesis', 'OCR_address_standardized_OFF_parenthesis',
    # 'OCR_Address_Type', 'OCR_Exit_Number', 'OCR_Main_Road', 'OCR_Secondary_Road',
    # 'Manually Verified?'
df[['OCR_Address_Type', 'OCR_zip_code', 'OCR_label', 'OCR_phone', 
    'OCR_address_standardized','OCR_Main_Road', 'OCR_Secondary_Road', 'OCR_state', 'OCR_chain', 
    'OCR_city_standardized', 'Flagged', 'Flag_Reason', 
    'OCR_address_standardized_ON_parenthesis', 
    'OCR_address_standardized_OFF_parenthesis', 
    'OCR_Exit_Number',
    'Manually Verified?']]
# Out:
#       OCR_Address_Type  OCR_zip_code  \
# 43950             Exit         84017
# 43951             Exit         84017
# 43952             Exit         84017
# 43953             Exit         84017
# 43954             Exit         84017
# ...                ...           ...
# 81401            empty         95691
# 81402            empty         95991
# 81403            empty         95991
# 81404            empty         95991
# 81405            empty         95991
#
#                                                OCR_label     OCR_phone  \
# 43950                               Holiday Hills ( 66 )  435-336-4421
# 43951                               Holiday Hills ( 66 )  435-336-4421
# 43952                                       Hills ( 66 )  435-336-4421
# 43953                                       Hills ( 66 )  435-336-4421
# 43954                             Holiday Hills ( 66 ) )  435-336-4421
# ...                                                  ...           ...
# 81401  1-80 Harbor Bus Truck / US & 50 Auto Xt 1 Stop...  916-372-2893
# 81402  4142 Dhami's CA Truck 99 ( 5 Stop mi S ( of Sh...  530-755-4564
# 81403  4142 Dhami's CA Truck 99 ( 5 Stop mi S ( of Sh...  530-755-4564
# 81404           Dhami's Truck Stop S ( of Shell town ) )  530-755-4564
# 81405           Dhami's Truck Stop S ( of Shell town ) )  530-755-4564
#
#                OCR_address_standardized OCR_Main_Road OCR_Secondary_Road  \
# 43950          I-80 Exit 162 ( UT 280 )          I-80                NaN
# 43951          I-80 Exit 162 ( UT 280 )          I-80                NaN
# 43952  I-80 Holiday Exit 162 ( UT 280 )          I-80                NaN
# 43953  I-80 Holiday Exit 162 ( UT 280 )          I-80                NaN
# 43954          I-80 Exit 162 ( UT 280 )          I-80                NaN
# ...                                 ...           ...                ...
# 81401                             Pilot         Pilot                NaN
# 81402       CA 99 & Obanion ( 10 mi S )         CA 99            Obanion
# 81403       CA 99 & Obanion ( 10 mi S )         CA 99            Obanion
# 81404       CA 99 & Obanion ( 10 mi S )         CA 99            Obanion
# 81405       CA 99 & Obanion ( 10 mi S )         CA 99            Obanion
#
#       OCR_state OCR_chain OCR_city_standardized  Flagged  \
# 43950        UT       NaN             Coalville    False
# 43951        UT       NaN             Coalville    False
# 43952        UT       NaN             Coalville    False
# 43953        UT       NaN             Coalville    False
# 43954        UT       NaN             Coalville    False
# ...         ...       ...                   ...      ...
# 81401        CA     Shell            Sacramento    False
# 81402        CA     Shell             Yuba City    False
# 81403        CA     Shell             Yuba City    False
# 81404        CA     Shell             Yuba City    False
# 81405        CA     Shell             Yuba City    False
#
#                                              Flag_Reason  \
# 43950                      Available in RVer and Trucker
# 43951                      Available in RVer and Trucker
# 43952                      Available in RVer and Trucker
# 43953                      Available in RVer and Trucker
# 43954                      Available in RVer and Trucker
# ...                                                  ...
# 81401  Multiple Name/ZIP/State/Road Matches Found (em...
# 81402  Multiple Name/ZIP/State/Road Matches Found (em...
# 81403  Multiple Name/ZIP/State/Road Matches Found (em...
# 81404  Multiple Name/ZIP/State/Road Matches Found (em...
# 81405  Multiple Name/ZIP/State/Road Matches Found (em...
#
#       OCR_address_standardized_ON_parenthesis  \
# 43950                              ( UT 280 )
# 43951                              ( UT 280 )
# 43952                              ( UT 280 )
# 43953                              ( UT 280 )
# 43954                              ( UT 280 )
# ...                                       ...
# 81401                                     NaN
# 81402                             ( 10 mi S )
# 81403                             ( 10 mi S )
# 81404                             ( 10 mi S )
# 81405                             ( 10 mi S )
#
#       OCR_address_standardized_OFF_parenthesis OCR_Exit_Number  \
# 43950                           I-80 Exit 162              162
# 43951                           I-80 Exit 162              162
# 43952                   I-80 Holiday Exit 162              162
# 43953                   I-80 Holiday Exit 162              162
# 43954                           I-80 Exit 162              162
# ...                                        ...             ...
# 81401                                    Pilot             NaN
# 81402                          CA 99 & Obanion             NaN
# 81403                          CA 99 & Obanion             NaN
# 81404                          CA 99 & Obanion             NaN
# 81405                          CA 99 & Obanion             NaN
#
#        Manually Verified?
# 43950                  No
# 43951                  No
# 43952                  No
# 43953                  No
# 43954                  No
# ...                   ...
# 81401  Please Verify This
# 81402  Please Verify This
# 81403  Please Verify This
# 81404  Please Verify This
# 81405  Please Verify This
#
# [4610 rows x 16 columns]

# %%
#shoe me df where Flag_Reason is "No matches found" and OCR_Address_Type is not 'Proper'
df[(df['Flag_Reason'] == "No matches found") & (df['OCR_Address_Type'] != 'Proper')]
# Out:
# Empty DataFrame
# Columns: [OCR_Unnamed: 0, OCR_filename, OCR_record_num, OCR_clean_line1, OCR_clean_line2, OCR_line3, OCR_city, OCR_zip_code, OCR_label, OCR_phone, OCR_address, OCR_parking, OCR_gray_parking, OCR_identifier, OCR_year, OCR_panel, OCR_major_city, OCR_state, OCR_chain, OCR_p_identifier, OCR_identifier2, OCR_identifier3, OCR_filename_standardized, OCR_clean_line1_standardized, OCR_clean_line2_standardized, OCR_line3_standardized, OCR_city_standardized, OCR_label_standardized, OCR_phone_standardized, OCR_address_standardized, OCR_parking_standardized, OCR_gray_parking_standardized, OCR_identifier_standardized, OCR_major_city_standardized, OCR_state_standardized, OCR_chain_standardized, OCR_p_identifier_standardized, OCR_identifier2_standardized, OCR_identifier3_standardized, Scraped_state_id, Scraped_state, Scraped_name, Scraped_href, Scraped_full_url, Scraped_stop_type, Scraped_Chain, Scraped_Latitude, Scraped_Longitude, Scraped_Highway, Scraped_Exit, Scraped_Street Address, Scraped_City, Scraped_State, Scraped_Postal Code, Scraped_Phone, Scraped_Phone 2, Scraped_Fax, Scraped_Hours of Operation, Scraped_# of Parking Spots, Scraped_# of Reserved Parking Spots, Scraped_# of Paid Parking Spots, Scraped_# of Fuel Lanes, Scraped_# of Showers, Scraped_# of Truck Service Bays, Scraped_Phone 3, Scraped_Mile Marker, Scraped_Unleaded, Scraped_Diesel, Scraped_Bulk Def, Scraped_Propane, Scraped_# of Men's Showers, Scraped_Phone 4, Scraped_Mailing Address, Scraped_Phone 5, Scraped_Road Name, Scraped_https, Scraped_htp, Scraped_http, match_accuracy, df1_source_row, df2_matched_row, Flagged, Flag_Reason, OCR_address_standardized_ON_parenthesis, OCR_address_standardized_OFF_parenthesis, OCR_Address_Type, OCR_Exit_Number, Exit_From_Address, Exit_From_Label, Is_Unclear_OCR, OCR_Main_Road, OCR_Secondary_Road, Manually Verified?]
# Index: []
#
# [0 rows x 93 columns]

# %%
#show me uque entries for Manually Verified?
print(df['Manually Verified?'].unique())
# Out:
# ['No' 'Please Verify This']

# %%
#show me all unique entrie sof Flag_Reason
print(df['Flag_Reason'].unique())
# Out:
# ['Available in RVer and Trucker'
#  'No Name/ZIP/State/Road matches found for empty address type'
#  'Multiple Name/ZIP/State/Road Matches Found (empty address type) - Match 1 of 4'
#  'Multiple Name/ZIP/State/Road Matches Found (empty address type) - Match 1 of 2'
#  nan
#  'Multiple Name/ZIP/State/Road Matches Found (empty address type) - Match 1 of 6'
#  'unclear OCR_address_standardized_OFF_parenthesis'
#  'Multiple matches found'
#  'Single Name/ZIP/State/Road Match Found (empty address type)'
#  'no matching ZIPCODE' 'No matches found'
#  'matching ZIPCODE, matching State, no matching Exit'
#  'Multiple Name/ZIP/State/Exit/Highway Matches Found - Match 1 of 2'
#  'Single Name/ZIP/State/Exit/Highway Match Found'
#  'Multiple Name/ZIP/State/Exit/Highway Matches Found - Match 1 of 4'
#  'No Phone/Name/ZIP/State/Exit/Highway matches found'
#  'matching ZIPCODE, matching State, matching Exit, no matching Highway/Exit/Street Address'
#  'Multiple Name/ZIP/State/Exit/Highway Matches Found - Match 2 of 2'
#  'Multiple Name/ZIP/State/Exit/Highway Matches Found - Match 2 of 4'
#  'Multiple Name/ZIP/State/Exit/Highway Matches Found - Match 3 of 4'
#  'Multiple Name/ZIP/State/Exit/Highway Matches Found - Match 4 of 4'
#  'Multiple Name/ZIP/State/Road Matches Found (empty address type) - Match 2 of 4'
#  'Multiple Name/ZIP/State/Road Matches Found (empty address type) - Match 3 of 4'
#  'Multiple Name/ZIP/State/Road Matches Found (empty address type) - Match 4 of 4'
#  'Multiple Name/ZIP/State/Road Matches Found (empty address type) - Match 2 of 2'
#  'Multiple Name/ZIP/State/Road Matches Found (empty address type) - Match 2 of 6'
#  'Multiple Name/ZIP/State/Road Matches Found (empty address type) - Match 3 of 6'
#  'Multiple Name/ZIP/State/Road Matches Found (empty address type) - Match 4 of 6'
#  'Multiple Name/ZIP/State/Road Matches Found (empty address type) - Match 5 of 6'
#  'Multiple Name/ZIP/State/Road Matches Found (empty address type) - Match 6 of 6']

# %%
df2 = pd.read_csv(r'C:\Users\clint\Desktop\Geocoding_Task\Matching_WebScrape\2.csv')
# 'state', 'name' 'full_url', 'stop_type', 'Chain', 'Highway', 'Exit', 'Street Address', 'City', #'State', 'Postal Code', 'Phone', 'Phone 2', 'Fax','Phone 3', 'Mile Marker','Phone 4', 'Mailing Address', 'Phone 5', 'Road Name',
df2[['Postal Code','state', 'name', 'full_url', 'stop_type', 'Chain', 'Highway',
    'Exit', 'Street Address', 'City', 'State',  'Phone',
    'Phone 2', 'Fax', 'Phone 3', 'Mile Marker', 'Phone 4',
    'Mailing Address', 'Phone 5', 'Road Name']]
# Out:
#       Postal Code    state                        name  \
# 0           36264  Alabama            205 TRUCK CENTER
# 1           36064  Alabama               231 FUEL STOP
# 2           35087  Alabama            4 WAY QUICK STOP
# 3           36345  Alabama  A. W. HERNDON OIL CO. INC.
# 4           35150  Alabama        ALLEN'S FOOD MART #9
# ...           ...      ...                         ...
# 15521       99586   Alaska              MENTASTA LODGE
# 15522       99780   Alaska       NORTHERN ENERGY CORP.
# 15523       99676   Alaska           TESORO NORTH  #78
# 15524       99701   Alaska      TESORO TRUCK STOP #101
# 15525       99780   Alaska     YOUNG'S CHEVRON SERVICE
#
#                                                 full_url stop_type  \
# 0      https://www.truckstopsandservices.com/location...   Trucker
# 1      https://www.truckstopsandservices.com/location...   Trucker
# 2      https://www.truckstopsandservices.com/location...   Trucker
# 3      https://www.truckstopsandservices.com/location...   Trucker
# 4      https://www.truckstopsandservices.com/location...   Trucker
# ...                                                  ...       ...
# 15521  http://www.rvandtravelers.com/location_details...      RVer
# 15522  http://www.rvandtravelers.com/location_details...      RVer
# 15523  http://www.rvandtravelers.com/location_details...      RVer
# 15524  http://www.rvandtravelers.com/location_details...      RVer
# 15525  http://www.rvandtravelers.com/location_details...      RVer
#
#               Chain    Highway  Exit            Street Address       City  \
# 0           chevron       I-20   205                7000 AL 46     HEFLIN
# 1      ind_dealer_1     US 231   NaN             7249 TROY HWY  PIKE ROAD
# 2            sunoco      AL 69   NaN                  14255 69      JOPPA
# 3             citgo     US 431   NaN              16326 US 431   HEADLAND
# 4             exxon       I-20   205              42020 US-280  SYLACAUGA
# ...             ...        ...   ...                       ...        ...
# 15521  ind_dealer_1       AK 1   NaN                78 TOK HWY     GAKONA
# 15522       tesoro-       AK 2   NaN           1314 ALASKA HWY        TOK
# 15523       tesoro-       AK 3   NaN         43721 S PARKS HWY   SUNSHINE
# 15524       tesoro-  S CUSHMAN   NaN            3569 S CUSHMAN  FAIRBANKS
# 15525       chevron       AK 1  AK 2  MILES 13 & 14 HWY ALASKA        TOK
#
#       State                         Phone  \
# 0        AL  256-463-7341 (TRAVEL CENTER)
# 1        AL  334-593-0332 (TRAVEL CENTER)
# 2        AL  256-796-6310 (TRAVEL CENTER)
# 3        AL  334-693-2451 (TRAVEL CENTER)
# 4        AL  256-245-2575 (TRAVEL CENTER)
# ...     ...                           ...
# 15521    AK  907-291-2324 (TRAVEL CENTER)
# 15522    AK                  907-883-4251
# 15523    AK                  907-733-3835
# 15524    AK  907-456-1122 (TRAVEL CENTER)
# 15525    AK                  907-883-2821
#
#                                      Phone 2           Fax Phone 3  \
# 0         256-463-7341 (HUNT BROTHERS PIZZA)  256-463-2022     NaN
# 1                                        NaN           NaN     NaN
# 2      256-796-6310 (KRISPY KRUNCHY CHICKEN)           NaN     NaN
# 3                                        NaN  334-693-2451     NaN
# 4                256-245-2575 (ALLEN'S DELI)           NaN     NaN
# ...                                      ...           ...     ...
# 15521                                    NaN           NaN     NaN
# 15522                                    NaN           NaN     NaN
# 15523                                    NaN           NaN     NaN
# 15524                                    NaN           NaN     NaN
# 15525                                    NaN           NaN     NaN
#
#       Mile Marker Phone 4 Mailing Address Phone 5 Road Name
# 0             NaN     NaN             NaN     NaN       NaN
# 1             NaN     NaN             NaN     NaN       NaN
# 2             NaN     NaN             NaN     NaN       NaN
# 3             NaN     NaN             NaN     NaN       NaN
# 4             NaN     NaN             NaN     NaN       NaN
# ...           ...     ...             ...     ...       ...
# 15521         NaN     NaN             NaN     NaN       NaN
# 15522     MM 1314     NaN             NaN     NaN       NaN
# 15523     MM 98.8     NaN             NaN     NaN       NaN
# 15524         NaN     NaN             NaN     NaN       NaN
# 15525         NaN     NaN             NaN     NaN       NaN
#
# [15526 rows x 20 columns]
